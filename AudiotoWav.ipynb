# %% [markdown]
# <a href="https://colab.research.google.com/github/KILjungjoon/Speech-Recognition/blob/main/AudiotoWav.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * How to convert all kinds of audio files to wav file

# %%
import subprocess
  
# convert mp3 to wav file
subprocess.call(['ffmpeg', '-i', '/content/script02.mp3',
                 '/content/script02.wav'])
# Out:
# 0

# %%
# !pip install librosa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# playing the wav file
import librosa.display 
import librosa 
import IPython.display as ipd
native01, sr01  = librosa.load('/content/script02.wav')
ipd.Audio('/content/script02.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
